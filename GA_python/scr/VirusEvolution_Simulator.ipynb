# %% [markdown]
# # reproducing Figures by implementing Genetic Algorithm (GA)

# %%
import glob
from makeFig import showFigure

# %%
# %%script bash
# n_processes=15
# n_delta=1.0
#
#
# echo `date`
#
# python pre_scripts/vLoad.py --n_delta $n_delta --n_processes $n_processes
#
# python pre_scripts/infPeriod.py --n_delta $n_delta --n_processes $n_processes
#
# python pre_scripts/vLoad_infPeriod.py --n_delta $n_delta --n_processes $n_processes
# Out:
# 2023年 10月19日 木曜日 02時48分40秒 JST
# file name :  vLoad.py
# n_delta : 1.0, n_processes : 15
# started at  2023-10-19 02:48:41.494168
# finish at  2023-10-19 02:48:45.286231
# file name :  infPeriod.py
# n_delta : 1.0, n_processes : 15
# started at  2023-10-19 02:48:45.666420
# finish at  2023-10-19 02:48:46.222607
# file name :  vLoad_infPeriod.py
# n_delta : 1.0, n_processes : 15
# started at  2023-10-19 02:48:46.556091
# finish at  2023-10-19 02:48:50.507336

# %%
# %%script bash
# n_processes=15
# n_delta=1.5
#
#
# echo `date`
#
# python pre_scripts/vLoad.py --n_delta $n_delta --n_processes $n_processes
#
# python pre_scripts/infPeriod.py --n_delta $n_delta --n_processes $n_processes
#
# python pre_scripts/vLoad_infPeriod.py --n_delta $n_delta --n_processes $n_processes
# Out:
# 2023年 10月19日 木曜日 02時48分50秒 JST
# file name :  vLoad.py
# n_delta : 1.5, n_processes : 15
# started at  2023-10-19 02:48:51.296039
# finish at  2023-10-19 02:48:54.889305
# file name :  infPeriod.py
# n_delta : 1.5, n_processes : 15
# started at  2023-10-19 02:48:55.281212
# finish at  2023-10-19 02:48:55.819960
# file name :  vLoad_infPeriod.py
# n_delta : 1.5, n_processes : 15
# started at  2023-10-19 02:48:56.168839
# finish at  2023-10-19 02:48:59.651577

# %% [markdown]
# ### Example 1. vaccination_rate = 0.0, imcomplete_isolation_prob (&xi;) = 0.0
# Figure 3., Extended Data Figure 1., Extended Data Figure 2., Figure S3-1., Figure S3-2., Figure S3-3., Figure S4-1., Figure S4-2.

# %%
# %%script bash
# n_processes=15
# iteration=300
# vaccination_rate=0.0
# imcomplete_isolation_prob=0.0
#
# echo `date`
# python main.py --iteration $iteration --f_range 0.1 0.2 0.3 --vaccination_rate $vaccination_rate --imcomplete_isolation_prob $imcomplete_isolation_prob --n_processes $n_processes
# Out:
# 2023年 10月19日 木曜日 02時48分59秒 JST
# file name :  main.py
# vaccination_prob : 0.0, imcomplete_isolation_prob : 0.0, n_processes : 15
# started at  2023-10-19 02:49:00.510011
# f_prob : 0.1, T_star_prob : 0.0125
# iter 0
# f_prob : 0.1, T_star_prob : 0.025
# iter 0
# f_prob : 0.1, T_star_prob : 0.0375
# iter 0
# f_prob : 0.1, T_star_prob : 0.05
# iter 0
# f_prob : 0.1, T_star_prob : 0.0625
# iter 0
# f_prob : 0.1, T_star_prob : 0.075
# iter 0
# f_prob : 0.1, T_star_prob : 0.0875
# iter 0
# f_prob : 0.1, T_star_prob : 0.1
# iter 0
# f_prob : 0.1, T_star_prob : 0.1125
# iter 0
# f_prob : 0.1, T_star_prob : 0.125
# iter 0
# f_prob : 0.2, T_star_prob : 0.0125
# iter 0
# f_prob : 0.2, T_star_prob : 0.025
# iter 0
# f_prob : 0.2, T_star_prob : 0.0375
# iter 0
# f_prob : 0.2, T_star_prob : 0.05
# iter 0
# f_prob : 0.2, T_star_prob : 0.0625
# iter 0
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# ...

# %%
# %%script bash
# n_processes=15
# iteration=100
# vaccination_rate=0.0
# imcomplete_isolation_prob=0.0
#
# echo `date`
# python GA.py --iteration $iteration --f_range 0.1 0.2 0.3 --vaccination_rate $vaccination_rate --imcomplete_isolation_prob $imcomplete_isolation_prob --n_processes $n_processes
# Out:
# 2023年 10月19日 木曜日 04時15分07秒 JST
# file name :  GA.py
# vaccination_prob : 0.0, imcomplete_isolation_prob : 0.0, n_processes : 15
# start at  2023-10-19 04:15:07.756622
# f:0.2, T:0.05, gen:0
# f:0.1, T:0.1125, gen:0
# f:0.1, T:0.0125, gen:0
# f:0.3, T:0.075, gen:0
# f:0.1, T:0.0375, gen:0
# f:0.2, T:0.075, gen:0
# f:0.1, T:0.125, gen:0
# f:0.2, T:0.1, gen:0
# f:0.2, T:0.125, gen:0
# f:0.3, T:0.125, gen:0
# f:0.2, T:0.0875, gen:0
# f:0.1, T:0.075, gen:0
# f:0.3, T:0.0875, gen:0
# f:0.1, T:0.1, gen:0
# f:0.3, T:0.1, gen:0
# f:0.2, T:0.1, gen:50
# f:0.3, T:0.125, gen:50
# f:0.1, T:0.125, gen:50
# f:0.1, T:0.1, gen:50
# f:0.1, T:0.1125, gen:50
# f:0.2, T:0.075, gen:50
# f:0.2, T:0.125, gen:50
# f:0.1, T:0.0125, gen:50
# f:0.1, T:0.075, gen:50
# f:0.2, T:0.05, gen:50
# f:0.1, T:0.0375, gen:50
# f:0.2, T:0.0875, gen:50
# f:0.3, T:0.0875, gen:50
# f:0.3, T:0.1, gen:50
# f:0.3, T:0.075, gen:50
# f:0.1, T:0.0625, gen:0
# f:0.3, T:0.05, gen:0
# f:0.1, T:0.025, gen:0
# f:0.3, T:0.0125, gen:0
# ...

# %%
Dmax = 80 # days

vaccination_rate, imcomplete_isolation_prob = 0.0, 0.0
f_range = [0.1, 0.2, 0.3]
chosen_T_range = [1/Dmax, 3/Dmax, 6/Dmax, 10/Dmax]
n_processes = 10

showFigure(vaccination_rate, imcomplete_isolation_prob, f_range, chosen_T_range, n_processes)
# Out:
# f : 0.1
# f : 0.2
# f : 0.3

# %% [markdown]
# ### Example 2. vaccination_rate = 0.5, imcomplete_isolation_prob (&xi;) = 0.0
# Figure S5-1., Figure S5-2.

# %%
# %%script bash
# n_processes=15
# iteration=300
# vaccination_rate=0.5
# imcomplete_isolation_prob=0.0
#
# echo `date`
# python main.py --iteration $iteration --f_range 0.1 0.2 0.3 --vaccination_rate $vaccination_rate --imcomplete_isolation_prob $imcomplete_isolation_prob --n_processes $n_processes
# Out:
# 2023年 10月19日 木曜日 04時35分16秒 JST
# file name :  main.py
# vaccination_prob : 0.5, imcomplete_isolation_prob : 0.0, n_processes : 15
# started at  2023-10-19 04:35:17.486095
# f_prob : 0.1, T_star_prob : 0.0125
# iter 0
# f_prob : 0.1, T_star_prob : 0.025
# iter 0
# f_prob : 0.1, T_star_prob : 0.0375
# iter 0
# f_prob : 0.1, T_star_prob : 0.05
# iter 0
# f_prob : 0.1, T_star_prob : 0.0625
# iter 0
# f_prob : 0.1, T_star_prob : 0.075
# iter 0
# f_prob : 0.1, T_star_prob : 0.0875
# iter 0
# f_prob : 0.1, T_star_prob : 0.1
# iter 0
# f_prob : 0.1, T_star_prob : 0.1125
# iter 0
# f_prob : 0.1, T_star_prob : 0.125
# iter 0
# f_prob : 0.2, T_star_prob : 0.0125
# iter 0
# f_prob : 0.2, T_star_prob : 0.025
# iter 0
# f_prob : 0.2, T_star_prob : 0.0375
# iter 0
# f_prob : 0.2, T_star_prob : 0.05
# iter 0
# f_prob : 0.2, T_star_prob : 0.0625
# iter 0
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# iter 100
# ...

# %%
# %%script bash
# n_processes=15
# iteration=100
# vaccination_rate=0.5
# imcomplete_isolation_prob=0.0
#
# echo `date`
# python GA.py --iteration $iteration --f_range 0.1 0.2 0.3 --vaccination_rate $vaccination_rate --imcomplete_isolation_prob $imcomplete_isolation_prob --n_processes $n_processes
# Out:
# 2023年 10月19日 木曜日 05時51分53秒 JST
# file name :  GA.py
# vaccination_prob : 0.5, imcomplete_isolation_prob : 0.0, n_processes : 15
# start at  2023-10-19 05:51:53.302011
# f:0.1, T:0.0125, gen:0
# f:0.2, T:0.1, gen:0
# f:0.2, T:0.125, gen:0
# f:0.1, T:0.1125, gen:0
# f:0.1, T:0.0375, gen:0
# f:0.1, T:0.1, gen:0
# f:0.2, T:0.05, gen:0
# f:0.3, T:0.1, gen:0
# f:0.3, T:0.125, gen:0
# f:0.1, T:0.125, gen:0
# f:0.1, T:0.075, gen:0
# f:0.3, T:0.075, gen:0
# f:0.3, T:0.0875, gen:0
# f:0.2, T:0.0875, gen:0
# f:0.2, T:0.075, gen:0
# f:0.2, T:0.125, gen:50
# f:0.1, T:0.125, gen:50
# f:0.3, T:0.1, gen:50
# f:0.1, T:0.0375, gen:50
# f:0.1, T:0.1125, gen:50
# f:0.1, T:0.075, gen:50
# f:0.3, T:0.125, gen:50
# f:0.1, T:0.1, gen:50
# f:0.2, T:0.1, gen:50
# f:0.3, T:0.075, gen:50
# f:0.3, T:0.0875, gen:50
# f:0.2, T:0.0875, gen:50
# f:0.1, T:0.0125, gen:50
# f:0.2, T:0.05, gen:50
# f:0.2, T:0.075, gen:50
# f:0.1, T:0.0625, gen:0
# f:0.3, T:0.05, gen:0
# f:0.1, T:0.025, gen:0
# f:0.3, T:0.0125, gen:0
# ...

# %%
Dmax = 80 # days

vaccination_rate, imcomplete_isolation_prob = 0.5, 0.0
f_range = [0.1, 0.2, 0.3]
chosen_T_range = [1/Dmax, 3/Dmax, 6/Dmax, 10/Dmax]
n_processes = 10

showFigure(vaccination_rate, imcomplete_isolation_prob, f_range, chosen_T_range, n_processes)
# Out:
# f : 0.1
# f : 0.2
# f : 0.3
